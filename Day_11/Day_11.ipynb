# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("../Dataset/supermarket_sales.csv")
df.head(5)
# Out:
#    Invoice ID Branch       City Customer Type  Gender            Product Line  \
# 0      352860      C  Naypyitaw        Normal  Female      Home and lifestyle
# 1      720146      A     Yangon        Member    Male       Health and beauty
# 2      660949      C     Yangon        Member  Female  Electronic accessories
# 3      516775      C     Yangon        Normal    Male       Sports and travel
# 4      936824      A     Yangon        Member  Female      Home and lifestyle
#
#    Unit Price  Quantity   Tax 5%     Total        Date      Payment  Rating
# 0       53.63         5  13.4075  281.5575  2023-01-15      Ewallet     7.3
# 1       56.12         4  11.2240  235.7040  2023-01-21  Credit card     8.4
# 2       76.75         6  23.0250  483.5250  2023-01-19         Cash     7.7
# 3       72.90         3  10.9350  229.6350  2023-03-01  Credit card     5.1
# 4       46.23         9  20.8035  436.8735  2023-03-30  Credit card     6.1

# %%
df.describe()
# Out:
#          Invoice ID  Unit Price    Quantity      Tax 5%       Total  \
# count     300.00000  300.000000  300.000000  300.000000  300.000000
# mean   542011.68000   55.606567    4.993333   13.789403  289.577470
# std    266617.69328   27.243701    2.650164   10.551001  221.571023
# min    109155.00000   10.020000    1.000000    0.510500   10.720500
# 25%    293977.75000   32.447500    2.750000    5.201750  109.236750
# 50%    553417.50000   56.730000    5.000000   10.767250  226.112250
# 75%    765930.25000   79.390000    7.000000   20.821875  437.259375
# max    997207.00000   99.940000    9.000000   44.653500  937.723500
#
#            Rating
# count  300.000000
# mean     7.033333
# std      1.696708
# min      4.000000
# 25%      5.600000
# 50%      7.100000
# 75%      8.500000
# max     10.000000

# %%
df.round(2)
# Out:
#      Invoice ID Branch       City Customer Type  Gender  \
# 0        352860      C  Naypyitaw        Normal  Female
# 1        720146      A     Yangon        Member    Male
# 2        660949      C     Yangon        Member  Female
# 3        516775      C     Yangon        Normal    Male
# 4        936824      A     Yangon        Member  Female
# ..          ...    ...        ...           ...     ...
# 295      700013      B     Yangon        Member  Female
# 296      730655      B  Naypyitaw        Member  Female
# 297      248506      B     Yangon        Member  Female
# 298      274927      B  Naypyitaw        Member  Female
# 299      386273      B     Yangon        Normal    Male
#
#                Product Line  Unit Price  Quantity  Tax 5%   Total        Date  \
# 0        Home and lifestyle       53.63         5   13.41  281.56  2023-01-15
# 1         Health and beauty       56.12         4   11.22  235.70  2023-01-21
# 2    Electronic accessories       76.75         6   23.02  483.52  2023-01-19
# 3         Sports and travel       72.90         3   10.94  229.64  2023-03-01
# 4        Home and lifestyle       46.23         9   20.80  436.87  2023-03-30
# ..                      ...         ...       ...     ...     ...         ...
# 295  Electronic accessories       88.12         7   30.84  647.68  2023-03-07
# 296     Fashion accessories       96.69         9   43.51  913.72  2023-01-25
# 297      Home and lifestyle       12.82         5    3.20   67.30  2023-02-23
# 298     Fashion accessories       75.81         1    3.79   79.60  2023-02-02
# 299       Health and beauty       91.86         7   32.15  675.17  2023-02-05
#
#          Payment  Rating
# 0        Ewallet     7.3
# 1    Credit card     8.4
# 2           Cash     7.7
# 3    Credit card     5.1
# 4    Credit card     6.1
# ..           ...     ...
# 295      Ewallet     8.0
# 296  Credit card     5.6
# 297  Credit card     9.4
# 298      Ewallet     8.0
# 299         Cash     7.4
#
# [300 rows x 13 columns]

# %%
corr_matrix=df.corr(numeric_only=True)
corr_matrix
# Out:
#             Invoice ID  Unit Price  Quantity    Tax 5%     Total    Rating
# Invoice ID    1.000000   -0.007099  0.028137  0.043817  0.043817 -0.074907
# Unit Price   -0.007099    1.000000 -0.026043  0.635629  0.635629 -0.089238
# Quantity      0.028137   -0.026043  1.000000  0.678833  0.678833 -0.039892
# Tax 5%        0.043817    0.635629  0.678833  1.000000  1.000000 -0.080700
# Total         0.043817    0.635629  0.678833  1.000000  1.000000 -0.080700
# Rating       -0.074907   -0.089238 -0.039892 -0.080700 -0.080700  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title("Correlation Heatmap - Supermarket Sales")
plt.savefig("correlation_heatmap.png")

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df[['Unit Price','Quantity','Tax 5%','Total','Rating']],corner=True)
plt.title('Pairplot')
plt.savefig("pairplot_Ratings")

# %% [markdown]
# # END
